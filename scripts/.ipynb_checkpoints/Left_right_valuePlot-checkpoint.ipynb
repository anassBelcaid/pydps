# %% [markdown]
# # Dps filter Left right value
#
# In this repo, We will illustrate the `left_right` values reported by the dps filter.
#
# A left(right) value if the value of a pixel when of the exrtremities of window  cross the pixel either from one of the edges (left or right)
#
# > ps: Should add a diagram

# %%
import torch 
from pydps import filter1d
from pydps.datasets import datasets
from pydps.vis import plot_edge_detection1d
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Getting a simple random data

# %%
data, target = datasets.load_random_dataset(20,200)

#visualizing the data
datasets.plot_dataset(data,targets=target,indices=np.random.choice(np.arange(20),12))
# Out:
# [ 1  1  3 12  6  3  6 10  8  2 18 18]

# %% [markdown]
# ## testing on a simple signal
#
# Now we will apply the filter that computes the following value:
# 1. The resulting line process
# 2. The gradient of the process
# 3. the left and right values

# %%
# creating the filter
window_size = 5
lam = 20

filt = filter1d.DpsFilter1D(lam,window_size)

# %%
#filtering the first signal
line, grad, (left,right) = filt(data[1])
plot_edge_detection1d(data[1],line,gt=target[1],gradient=grad)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-b4e658887b0e> in <module>
#       1 #filtering the first signal
#       2 line, grad, (left,right) = filt(data[1])
# ----> 3 plot_edge_detection1d(data[1],line,gt=target[1],gradient=grad)
#
# ~/github/anass/software/python/dps/pydps/vis.py in plot_edge_detection1d(noised, edge, gt, gradient)
#      51     """
#      52
# ---> 53     fig,ax= plt.subplot(1,2,figsize=(12,6))
#      54
#      55     #first plot
#
# ~/anaconda3/envs/vision/lib/python3.6/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1082
#    1083     fig = gcf()
# -> 1084     a = fig.add_subplot(*args, **kwargs)
#    1085     bbox = a.bbox
#    1086     byebye = []
#
# ~/anaconda3/envs/vision/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
# ...

# %%
e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-094e3afb2fe8> in <module>
# ----> 1 e
#
# NameError: name 'e' is not defined
